# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(pd.__version__)

# %%
directory = "/content/drive/MyDrive/422project/dataset/dataset/covid-liver.csv"

dataset=pd.read_csv(directory, encoding='cp1252')

# %% [markdown]
# # **Read Dataset: .csv/.xlsx to DataFrame**

# %% [markdown]
# # **Dataset Analysis**
#
# - shape
# - columns
# - head()
# - sample()
# - describe()
# - finding categorical features
# - checking if any null/nan values
# - filtering data instances based on indices
# - filtering data instances based on conditional statements

# %%
dataset.shape

# %%
dataset.columns

# %%
dataset.head(10)

# %%
dataset.sample(5)

# %%
dataset.describe()

# %%
dataset.info()

# %%
dataset["Mode_Presentation"].unique()
dataset["Alive_Dead"].unique()

# %%
dataset.isnull()

# %%
dataset.isnull().sum()

# %% [markdown]
# # **Dataset Visualization**
#
# - Dataset biased or not
# - Histogram
# - Scatter Plot
# - Bar chart
# - etc.

# %% [markdown]
# # **Dataset Pre-processing**
#
# - Null/NaN values handling
#
#     a) Delete Rows
#
#     b) Delete Columns
#
#     c) Impute Values
#
# - Encoding Categorical Features
#
# - Feature Scaling

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# The imputation strategy:  mean, median, most_frequent, constant

impute = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

list_of_features = ["Bleed", "Etiology", "Cirrhosis","Size","HCC_TNM_Stage","HCC_BCLC_Stage", "ICC_TNM_Stage","Treatment_grps","Type_of_incidental_finding","Surveillance_programme","Surveillance_effectiveness","Mode_of_surveillance_detection","Time_diagnosis_1st_Tx","Date_incident_surveillance_scan","Time_MDM_1st_treatment","Time_decisiontotreat_1st_treatment","Prev_known_cirrhosis","Months_from_last_surveillance","Type_of_incidental_finding"]

dataset[list_of_features] = impute.fit_transform(dataset[list_of_features])

# %%
new_path="/content/drive/MyDrive/422project/dataset/dataset/new_dataset.csv"
dataset.to_csv(new_path,index=False)

# %%
dataset.isnull().sum()

# %% [markdown]
# directory = "/content/drive/MyDrive/CSE422/Dataset/covid-liver.csv"
# dataset=pd.read_csv(directory)
#
# #dataset=pd.read_csv(directory, encoding='cp1252')

# %%
dataset

# %%
dataset.info()

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Year'] = enc.fit_transform(dataset['Year'])

# Compare the two columns
print(dataset[['Year']].head(200))

# %%
#dataset['Year_enc'] = dataset['Year'].map({'Prepandemic':0,'Pandemic': 1})

# %%
#dataset=dataset.drop(["Year"],axis=1)

# %%
dataset

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Bleed'] = enc.fit_transform(dataset['Bleed'])

# Compare the two columns
print(dataset[['Bleed']].head())

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Mode_Presentation'] = enc.fit_transform(dataset['Mode_Presentation'])

# Compare the two columns
print(dataset[['Mode_Presentation']].head())

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Gender'] = enc.fit_transform(dataset['Gender'])

# Compare the two columns
print(dataset[['Gender']].head())

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Etiology'] = enc.fit_transform(dataset['Etiology'])

# Compare the two columns
print(dataset[['Etiology']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Cirrhosis'] = enc.fit_transform(dataset['Cirrhosis'])

# Compare the two columns
print(dataset[['Cirrhosis']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['HCC_TNM_Stage'] = enc.fit_transform(dataset['HCC_TNM_Stage'])

# Compare the two columns
print(dataset[['HCC_TNM_Stage']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['HCC_BCLC_Stage'] = enc.fit_transform(dataset['HCC_BCLC_Stage'])

# Compare the two columns
print(dataset[['HCC_BCLC_Stage']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['ICC_TNM_Stage'] = enc.fit_transform(dataset['ICC_TNM_Stage'])

# Compare the two columns
print(dataset[['ICC_TNM_Stage']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Treatment_grps'] = enc.fit_transform(dataset['Treatment_grps'])

# Compare the two columns
print(dataset[['Treatment_grps']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Alive_Dead'] = enc.fit_transform(dataset['Alive_Dead'])

# Compare the two columns
print(dataset[['Alive_Dead']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Type_of_incidental_finding'] = enc.fit_transform(dataset['Type_of_incidental_finding'])

# Compare the two columns
print(dataset[['Type_of_incidental_finding']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Surveillance_programme'] = enc.fit_transform(dataset['Surveillance_programme'])

# Compare the two columns
print(dataset[['Surveillance_programme']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Surveillance_effectiveness'] = enc.fit_transform(dataset['Surveillance_effectiveness'])

# Compare the two columns
print(dataset[['Surveillance_effectiveness']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Mode_of_surveillance_detection'] = enc.fit_transform(dataset['Mode_of_surveillance_detection'])

# Compare the two columns
print(dataset[['Mode_of_surveillance_detection']].head(100))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Date_incident_surveillance_scan'] = enc.fit_transform(dataset['Date_incident_surveillance_scan'])

# Compare the two columns
print(dataset[['Date_incident_surveillance_scan']].head(300))

# %%
from sklearn.preprocessing import LabelEncoder

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
dataset['Prev_known_cirrhosis'] = enc.fit_transform(dataset['Prev_known_cirrhosis'])

# Compare the two columns
print(dataset[['Prev_known_cirrhosis']].head(100))

# %%
# feature scaling
from sklearn.preprocessing import MinMaxScaler


list_of_features = ["Age", "Size","Month","Mode_Presentation","Etiology","HCC_TNM_Stage","HCC_BCLC_Stage","ICC_TNM_Stage","Treatment_grps","Survival_fromMDM","Type_of_incidental_finding","Mode_of_surveillance_detection","Time_diagnosis_1st_Tx","PS","Time_MDM_1st_treatment","Time_decisiontotreat_1st_treatment","Months_from_last_surveillance"]

scaler = MinMaxScaler()

dataset[list_of_features] = scaler.fit_transform(dataset[list_of_features])

# %%
dataset

# %% [markdown]
# # **Feature Selection**

# %%
# from sklearn.datasets import load_wine
# covid_liver=load_wine()
# covid_liver_df=pd.DataFrame(covid_liver['data'], features=covid_liver['Cancer','Year', 'Month','Bleed','Mode_Presentation','Age','Gender','Etiology','Cirrhosis','Size','HCC_TNM_Stage','ICC_TNM_Stage','Treatment_grps','Survival_fromMDM','Alive_Dead','Type_of_incidental_finding','Surveillance_programme','Surveillance_effectiveness','Mode_of_surveillance_detection','Time_diagnosis_1st_Tx','Date_incident_surveillance_scan','PS','Time_MDM_1st_treatment','Time_decisiontotreat_1st_treatment','Prev_known_cirrhosis','Months_from_last_surveillance'])
# covid_liver_corr=covid_liver_df.corr()
# covid_liver_corr

# %%
covid_liver_corr=dataset.corr()
covid_liver_corr

# %% [markdown]
# # **Dataset Splitting**
#
# - Training Set
#
# - Testing Set

# %%
import seaborn as sns
sns.heatmap(covid_liver_corr,cmap='YlGnBu')

# %%
import matplotlib.pyplot as plt
sns.set(font_scale=1.1)
corr_train=dataset.corr()
plt.figure(figsize=(30,25))
sns.heatmap(corr_train,annot=True,fmt='.3f',cmap='YlOrBr',linewidth=5,cbar=True)
plt.show()

# %%
#create a list of redundant column to drop
to_drop=['Cancer','Age','Gender','Cirrhosis','HCC_BCLC_Stage','HCC_TNM_Stage','Treatment_grps','Type_of_incidental_finding','Surveillance_programme','Mode_of_surveillance_detection','Time_diagnosis_1st_Tx','PS','Prev_known_cirrhosis','Months_from_last_surveillance','Time_decisiontotreat_1st_treatment']
new_dataset=dataset.drop(to_drop, axis=1)
new_dataset.head()

# %% [markdown]
# # **Dataset Training**
#
# Classification Problem
#
# - SVM
#
# - Decision Tree
#
# - K-nearest Neighbors
#
# - Logistic Regression
#
# Regression Problem
# - https://www.upgrad.com/blog/types-of-regression-models-in-machine-learning/

# %% [markdown]
# # **Dataset Testing with the unseen x_data**

# %% [markdown]
# # **Result analysis of used models**

# %%
#Correalation showcase
sns.set(font_scale=1.1)
correlation_train = dataset.corr()
mask = np.triu(correlation_train.corr())
plt.figure(figsize=(20, 12))
sns.heatmap(correlation_train,
            annot=True,
            fmt='.2f',
            cmap='YlGn',
            linewidths=1,
            cbar=True)

plt.show()

# %%
correlation_threshold = 0.2
relevant_features = correlations['Alive_Dead'][abs(correlations['Alive_Dead']) > correlation_threshold].index.tolist()
print("Relevant features:", relevant_features)

# %%
relevant_correlations = correlations.loc[relevant_features, relevant_features]

# Set up the figure size
plt.figure(figsize=(10, 8))

# Create a custom heatmap for relevant features
sns.heatmap(relevant_correlations, annot=True, cmap='YlGn', center=0)

# Add title
plt.title('Correlation Heatmap for Relevant Features')

# Show the plot
plt.show()

# %%
# Top correlated variables vs condition:

correlations = dataset.corrwith(dataset['Alive_Dead']).iloc[:].to_frame()
correlations['Correlation'] = correlations[0].abs()
sorted_correlations = correlations.sort_values('Correlation', ascending=False)['Correlation']
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(sorted_correlations.to_frame()[sorted_correlations>=.2], cmap='YlGn', annot=True, vmin=-1, vmax=1,linewidths=1,fmt='.5f', ax=ax);

# %% [markdown]
# # **Summary of your project**

# %% [markdown]
# <<< summary >>>
